# %%
#Step 1. 필요한 모듈과 라이브러리를 로딩하고 검색어를 입력 받습니다
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

query_txt = "동서대학교"

#Step 2. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
path = "C:\py_temp\chromedriver\chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://www.naver.com")
time.sleep(2)

element = driver.find_element(By.ID,"query")

element.send_keys(query_txt)

driver.find_element(By.ID,'search-btn').click()

driver.find_element(By.LINK_TEXT,'VIEW').click()

driver.find_element(By.LINK_TEXT,'블로그').click()

all_html = driver.page_source 
soup = BeautifulSoup(all_html, 'html.parser')
getlist = soup.find('ul', class_='lst_total')


for i in getlist:
    print(i.text.strip())
    print("\n")
# Out:
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.02.03.   go Edu      동서대학교 정시등급(22) 수능 최고 평균등급 수시 전형별 입결    동서대학교 정시등급에 이어 수시등급 평균을 살펴 보고 있는데요, 일반 대학교... 학생부종합 동서대 수시등급 구 자기추천자 전형방법은 학생부교과(교과, 비교과)...       15
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          6일 전   동서대학교 홍보대사      동서대학교 치위생학과 보건소 실습 후기    #DONGSEOUNIVERSITY #BDAD #MYBRIGHTFUTURE #东西大学 #全球 #東西大学校 #世界的な #동서대학교 #부산4년제 #대학교홍보대사 #아임동서 #대학생 #대학생활 #꿀팁 #대학일기...       17
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          공식 2023.05.22.   동서대학교 공식 블로그      동서대학교 최고경영자과정 워크샵 개최    동서대학교 최고경영자과정 워크샵 개최 동서대학교 최고경영자과정에서는 2023년 5월 19일(금)부터 20일(토)까지 거제뷰리조트에서 춘계 워크샵을 개최했다. 이번 춘계...       2
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.05.22.   드림하이 에꼴      2023 동서대 수시등급... 2024 동서대학교 수시 정시 주요사항    2023 동서대 수시등급 정시등급 입결 내신 정시컷 경쟁률 2024 동서대학교 수시 정시 주요사항 ■ 2024학년 동서대학교 입시에서는 총 2,400명을 모집하며 그 중 3.6%인...       13
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.01.15.   동서대학교 광고홍보학과      [동서대학교/광고홍보학과]GBTI-완벽적응 광홍이    그 전에는 동서대학교 센텀캠퍼스에 위치한 관광학부에 있었어요 ✌ 코로나가 터지고 학교는 가는 날 보다 집에서 화상강의, 혹은 온라인 강의로 대체되어...       9
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.05.16.   헨리의 하루공부      2023 동서대 수시등급 및 경쟁률 등록금, 2024 동서대학교...     동서대학교 경쟁률 및 등록금 동서대 경쟁률을 전형별로 살펴보면 일반계 교과전형 경쟁률은 6.54:1, 학생부 면접전형 경쟁률은 6.07:1, 학생부 종합 전형 경쟁률은 6.77...       16
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.04.10.   학습플래너 아진쌤      동서대학교 간호학과, 보다 높은 합격률로!    또한 동서대학교 간호학과는 다른 편입대학보다 모집인원도 많은 편인데요. 일반 4명, 학사 18명이에요. 이 때 일반 = 전문대학 졸업 이상의 학력 혹은 대학교 2학년 과정...       5
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.04.06.   교육 블로거 패트릭쌤의 교육 정보 팩토리      동서대 학교 수시 등급 컷 수시입결 5개 전형별 환산등급...     오늘 포스팅은 동서대학교 수시등급 수시입결 결과를 5개 전형자료를 근거로 올려드렸고, 그 결과에 따른 학과특성을 함께 살펴보았습니다. 그 결과 이 대학교의...       27
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          1시간 전   행복걷기멘토 미숙쌤      학습 수기 공모전 장려상 수상 동서대학교 미래커리어대학    그때 걷기를 좋아하던 언니가 동서대 미래커리어대학에서 LIFE 사업으로... 꿈의 동서대학교 미래커리어대학 시니어운동처방학과 저는 정말 행운아입니다. 대학의...       11
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          6일 전   대학교 정보와 최신 소식 전하기      독특함과 특성화로 상승세를 타고 있는 부산 동서대학교    부산 사상구 주례동에 자리 잡고 있는 동서대학교는 4년제 사립대학교입니다. 작년(2022년)에 개교 30주년을 맞이한 동서대학교는 과거 동서공과대학이 모체가 된...       6
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2일 전   부산여성신문      동서대학교, 디지털 UP싸이클링 DAY 특강 ‘AI Talk...     동서대학교, 디지털 UP싸이클링 DAY 특강 ‘AI Talk Talk’ 열려 동서대학교 디지털 역량 강화 교육사업단(단장 문미경)이 6월 13일, 디지털 역량 강화를 위한 AI...
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          공식 2022.11.26.   부산광역시 대표 블로그      대학 캠퍼스 투어 : 동서대학교    기독교 정신을 바탕으로 건학된 동서대학교는 대학교 캠퍼스가 있는 것이... ▲민석동산 울창한 나무들과 숲으로 둘러싸인 동서대학에서는 민석동산이라고 쓰인...       17
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.03.07.   대학교 입시 연구소      [수시] 2024학년도 입시 동서대학교 수시등급, 입결    대학교 입시 연구소 입니다. 동서대학교 2023년 입시 결과는 업데이트 전으로, 2022년 데이터를 참고하여 수시등급을 알아보겠습니다. 대학교 정보가 업데이트되는...       2
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          공식 2023.02.22.   동서대학교 공식 블로그      [동서대]동서대학교 제10대 장제국 총장 취임식 거행    그것만이 우리 대학을 살리는 길이다”라고 당부 동서대학교 제10대 장제국 총장 취임식이 2월 21일 소향아트홀에서 열렸다. 이날 행사에는 박동순 학교법인 동서학원...       7
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          3일 전   동서대학교 홍보대사      [동서대] 동서대학교 5월 마지막 소!식!    종강을 향해 달려보자구 #DONGSEOUNIVERSITY #BDAD #MYBRIGHTFUTURE #东西大学 #全球 #東西大学校 #世界的な #동서대학교 #부산4년제 #대학교홍보대사 #아임동서 #대학생...       10
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          공식 2022.08.08.   유웨이 공식블로그      2023학년도 동서대학교 수시 전형방법, 모집요강, 수능 최저...     최종적으로 지원하기 전에 대학교 입학처 홈페이지에서 다시 한 번 확인해주세요 :D #동서대 #동서대학교 #동서대학교수시전형방법 #동서대수시전형방법...       6
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.05.19.   절대 대학가      2023 동서대 수시등급 (예비번호, 동서대학교)    2023학년도 동서대 수시등급을 안내드립니다. 올해 동서대학교에 수시 지원을 고려 중인 분들은 이 성적을 참고하시길 바랍니다. 이전 과년도 성적은 이 블로그에...       4
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.02.12.   동서대학교 광고홍보학과      [동서대학교/광고홍보학과] 이곳이 궁금해? - 대강당 편    출처: 동서대학교 유튜브 (동서대 맛보기 캠퍼스투어_아랫동네 편) 그럼 순식간에 바로 대강당에 도착!! 조금만 걸으면 도착이라 수업과 채플시간이 바로 이어져있어도...       8
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023.01.11.   ● 대학가자! ●      2022학년도 동서대학교 수시등급    동서대학교는 4년제 사립 대학교에요~ 동서대학교는 부산광역시 사상구 주례로 47에 위치하고 있어요! 2021년도 기준 전체 재학생 수는 9,296명이며 연평균...       17
#
#
#
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기          2023